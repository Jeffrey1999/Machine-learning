# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeffrey1999/Machine-learning/blob/main/yolov8x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %mkdir /content/drive/MyDrive/yolov8_x

# %%
# %cd /content/drive/MyDrive/yolov8_x
# Out:
# /content/drive/MyDrive/yolov8_x

# %%
# !nvidia-smi
# Out:
# Tue Sep 19 11:13:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.8/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %mkdir /content/drive/MyDrive/yolov8_x/datasets

# %%
# %cd /content/drive/MyDrive/yolov8_x/datasets
# Out:
# /content/drive/MyDrive/yolov8_x/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rpkbzrBvmioBl20R9byH")
project = rf.workspace("automatic-license-plate-recognition-kxxzn").project("license-plate-detection-ee9ca")
dataset = project.version(7).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
# ...

# %%
yolo detect train resume model=last.pt  # resume training

# %%
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=100 lr0=0.001  plots=True
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 176MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/content/drive/MyDrive/yolov8_x/datasets/runs/detect/train/weights/last.pt data=/content/drive/MyDrive/yolov8_x/datasets/License-Plate-Detection-7/data.yaml epochs=100 lr0=0.001  plots=True save=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect train resume model=/content/drive/MyDrive/yolov8_x/datasets/runs/detect/train/weights/last.pt data=/content/drive/MyDrive/yolov8_x/datasets/License-Plate-Detection-7/data.yaml # resume training
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
